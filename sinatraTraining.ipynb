# %% [markdown]
# # Sinatra Training
#
# In this tutorial you might learn how to train the model of your dataset.
#
# Firt thing you need is to have the last git commit in your folder. You can clone a repository if you are using git.
#
#     git clone https://github.com/BrunoCuevas/sinatra
#
# Or you can just go to that webpage and download a zip file that contains all the code.
#
# Second thing you need is to have your data in an accesible format. There is a file in the repository called "tablaNombres.csv". Just look at the format. It's really simple:
#
# - class (a number for the class)
# - the filename
# - a label of the class (just to double-check that you didn't get wrong).
#
# Once you have this, you can open your ipython terminal and type:
#
#     %run exersice2.py path2DatasetFile path2OutputFile

# %%
# %run exersice2.py ../dataset1/dataset1.txt data11.txt
# Out:
# reading table ../dataset1/dataset1.txt
# task completed
# reading table /home/charizard/Dropbox/UNIVERSIDAD/Master/Workshop/datasetTrial/testing.csv
# task completed
# reading fu
# /home/charizard/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /home/charizard/Dropbox/UNIVERSIDAD/Master/Workshop/sinatra/sinatraFrontEnd.py:160: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   tokkenRow = np.zeros(tokkenLength);
# ...

# %% [markdown]
# As you can see, the program complains a lot. Ignore it. We'll have time to fix that in a near future. The output of the program is a tsv table (tab separated values). Since weka and python ML-methods recognise classes in a different way (for ewka, they must be nominal and for python, they must be numbers), the classes are give back as numbers. Weka does need letters or something nominal (it's kinda stupid, but this is how it works). So we need to substitute the last term of the columns by a specific letter. If you are doing right and you are using linux, this is trivial. Supossing that your file name is "data11.txt". Just type then:
#     cat data11.txt | sed -r s/0.0000&/A/g > dataBuffer.txt
#     cat dataBuffer.txt | sed -r s/1.0000&/B/g > data11.txt
#
# And so on. IMPORTANT: Jupyter doesn't let me write the character dolar, so I wrote an ampersand within the command. But it's a dollar.
#
# Once you have subsititued the n numbers by n letters, you can open it on weka. Remember that it is not an arff file, so don't get scared if you don't see the file when you try to open the file. Just change type to "all the files", and you'll see. The program might complain, but just ignore it. Then, go to classify, and play. My favourite method is logistic regression (within the functions), but is true that it isnt really good when facing non linear problems. Neural Networks are cool but they take much time and resources. Bayessian methods are usually poor, but they are cheap. You can also use SMO, some metaclassifier, and all that.
#
# Try a few of them and tell me how does it work
